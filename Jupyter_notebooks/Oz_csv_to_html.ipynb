# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 4.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.1 MB 36.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 6.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
word_count_df = pd.read_csv('Oz_word_count.csv') 
word_count_df
# Out:
#       Unnamed: 0                       title       word    n
# 0              1  The Wonderful Wizard of Oz    dorothy  346
# 1              2    The Marvelous Land of Oz        tip  288
# 2              3    The Marvelous Land of Oz  scarecrow  281
# 3              4  The Wonderful Wizard of Oz  scarecrow  224
# 4              5    The Marvelous Land of Oz      horse  183
# ...          ...                         ...        ...  ...
# 6733        6734  The Wonderful Wizard of Oz     yelled    1
# 6734        6735  The Wonderful Wizard of Oz  yellowing    1
# 6735        6736  The Wonderful Wizard of Oz     yonder    1
# 6736        6737  The Wonderful Wizard of Oz       york    1
# 6737        6738  The Wonderful Wizard of Oz  youngster    1
#
# [6738 rows x 4 columns]

# %%
word_count_df, setindex=["title"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-e1d8fd9936ff> in <module>
# ----> 1 word_count_df, setindex=["title"]
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
word_frequency = word_count_df.iloc[:, 1:4]

# %%
data_html = word_frequency.to_html()
data_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>title</th>\n      <th>word</th>\n      <th>n</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>The Wonderful Wizard of Oz</td>\n      <td>dorothy</td>\n      <td>346</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>The Marvelous Land of Oz</td>\n      <td>tip</td>\n      <td>288</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>The Marvelous Land of Oz</td>\n      <td>scarecrow</td>\n      <td>281</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>The Wonderful Wizard of Oz</td>\n      <td>scarecrow</td>\n      <td>224</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>The Marvelous Land of Oz</td>\n      <td>horse</td>\n      <td>183</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>The Wonderful Wizard of Oz</td>\n      <td>woodman</td>\n      <td>177</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>The Wonderful
# ...

# %%
text_file = open("index.html", "w")
text_file.write(data_html)
text_file.close()


# text_file = open("index.html", "w")
# text_file.write(html)
# text_file.close()
