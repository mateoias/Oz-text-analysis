# %%
text <- c("Because I could not stop for Death -",
          "He kindly stopped for me -",
          "The Carriage held but just Ourselves -",
          "and Immortality")

text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9eb6383b29fc> in <module>
# ----> 1 text <- c("Because I could not stop for Death -",
#       2           "He kindly stopped for me -",
#       3           "The Carriage held but just Ourselves -",
#       4           "and Immortality")
#       5
#
# NameError: name 'text' is not defined

# %%
library(dplyr)
text_df <- tibble(line = 1:4, text = text)

text_df
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#   line text
# 1 1    Because I could not stop for Death -
# 2 2    He kindly stopped for me -
# 3 3    The Carriage held but just Ourselves -
# 4 4    and Immortality

# %%
library(tidytext)

text_df %>%
  unnest_tokens(word, text)
# Out:
#    line word
# 1  1    because
# 2  1    i
# 3  1    could
# 4  1    not
# 5  1    stop
# 6  1    for
# 7  1    death
# 8  2    he
# 9  2    kindly
# 10 2    stopped
# 11 2    for
# 12 2    me
# 13 3    the
# 14 3    carriage
# 15 3    held
# 16 3    but
# 17 3    just
# 18 3    ourselves
# 19 4    and
# 20 4    immortality

# %%
library(janeaustenr)
library(dplyr)
library(stringr)

original_books <- austen_books() %>%
  group_by(book) %>%
  mutate(linenumber = row_number(),
         chapter = cumsum(str_detect(text, regex("^chapter [\\divxlc]",
                                                 ignore_case = TRUE)))) %>%
  ungroup()

original_books
# Out:
#       text
# 1     SENSE AND SENSIBILITY
# 2
# 3     by Jane Austen
# 4
# 5     (1811)
# 6
# 7
# 8
# 9
# 10    CHAPTER 1
# 11
# 12
# 13    The family of Dashwood had long been settled in Sussex.  Their estate
# 14    was large, and their residence was at Norland Park, in the centre of
# 15    their property, where, for many generations, they had lived in so
# 16    respectable a manner as to engage the general good opinion of their
# 17    surrounding acquaintance.  The late owner of this estate was a single
# 18    man, who lived to a very advanced age, and who for many years of his
# 19    life, had a constant companion and housekeeper in his sister.  But her
# 20    death, which happened ten years before his own, produced a great
# 21    alteration in his home; for to supply her loss, he invited and received
# 22    into his house the family of his nephew Mr. Henry Dashwood, the legal
# 23    inheritor of the Norland estate, and the person to whom he intended to
# 24    bequeath it.  In the society of his nephew and niece, and their
# 25    children, the old Gentleman's days were comfortably spent.  His
# 26    attachment to them all increased.  The constant attention of Mr. and
# 27    Mrs. Henry Dashwood to his wishes, which proceeded not merely from
# 28    interest, but from goodness of heart, gave him every degree of solid
# 29    comfort which his age could receive; and the cheerfulness of the
# 30    children added a relish to his existence.
# ...   ...
# 73393
# 73394 Her recent good offices by Anne had been enough in themselves, and
# 73395 their marriage, instead of depriving her of one friend, secured her
# 73396 two.  She was their earliest visitor in their settled life; and Captain
# 73397 Wentworth, by putting her in the way of recovering her husband's
# 73398 property in the West Indies, by writing for her, acting for her, and
# 73399 seeing her through all the petty difficulties of the case with the
# 73400 activity and exertion of a fearless man and a determined friend, fully
# 73401 requited the services which she had rendered, or ever meant to render,
# 73402 to his wife.
# 73403
# 73404 Mrs Smith's enjoyments were not spoiled by this improvement of income,
# 73405 with some improvement of health, and the acquisition of such friends to
# 73406 be often with, for her cheerfulness and mental alacrity did not fail
# 73407 her; and while these prime supplies of good remained, she might have
# 73408 bid defiance even to greater accessions of worldly prosperity.  She
# 73409 might have been absolutely rich and perfectly healthy, and yet be
# 73410 happy.  Her spring of felicity was in the glow of her spirits, as her
# 73411 friend Anne's was in the warmth of her heart.  Anne was tenderness
# 73412 itself, and she had the full worth of it in Captain Wentworth's
# 73413 affection.  His profession was all that could ever make her friends
# 73414 wish that tenderness less, the dread of a future war all that could dim
# 73415 her sunshine.  She gloried in being a sailor's wife, but she must pay
# 73416 the tax of quick alarm for belonging to that profession which is, if
# 73417 possible, more distinguished in its domestic virtues than in its
# 73418 national importance.
# 73419
# 73420
# 73421
# 73422 Finis
#       book                linenumber chapter
# 1     Sense & Sensibility  1         0
# 2     Sense & Sensibility  2         0
# 3     Sense & Sensibility  3         0
# 4     Sense & Sensibility  4         0
# 5     Sense & Sensibility  5         0
# 6     Sense & Sensibility  6         0
# 7     Sense & Sensibility  7         0
# 8     Sense & Sensibility  8         0
# 9     Sense & Sensibility  9         0
# 10    Sense & Sensibility 10         1
# 11    Sense & Sensibility 11         1
# 12    Sense & Sensibility 12         1
# 13    Sense & Sensibility 13         1
# 14    Sense & Sensibility 14         1
# 15    Sense & Sensibility 15         1
# 16    Sense & Sensibility 16         1
# 17    Sense & Sensibility 17         1
# 18    Sense & Sensibility 18         1
# 19    Sense & Sensibility 19         1
# 20    Sense & Sensibility 20         1
# 21    Sense & Sensibility 21         1
# 22    Sense & Sensibility 22         1
# 23    Sense & Sensibility 23         1
# 24    Sense & Sensibility 24         1
# 25    Sense & Sensibility 25         1
# 26    Sense & Sensibility 26         1
# 27    Sense & Sensibility 27         1
# 28    Sense & Sensibility 28         1
# 29    Sense & Sensibility 29         1
# 30    Sense & Sensibility 30         1
# ...   ...                 ...        ...
# 73393 Persuasion          8299       24
# 73394 Persuasion          8300       24
# 73395 Persuasion          8301       24
# 73396 Persuasion          8302       24
# 73397 Persuasion          8303       24
# 73398 Persuasion          8304       24
# 73399 Persuasion          8305       24
# 73400 Persuasion          8306       24
# 73401 Persuasion          8307       24
# 73402 Persuasion          8308       24
# 73403 Persuasion          8309       24
# 73404 Persuasion          8310       24
# 73405 Persuasion          8311       24
# 73406 Persuasion          8312       24
# 73407 Persuasion          8313       24
# 73408 Persuasion          8314       24
# 73409 Persuasion          8315       24
# 73410 Persuasion          8316       24
# 73411 Persuasion          8317       24
# 73412 Persuasion          8318       24
# 73413 Persuasion          8319       24
# 73414 Persuasion          8320       24
# 73415 Persuasion          8321       24
# 73416 Persuasion          8322       24
# 73417 Persuasion          8323       24
# 73418 Persuasion          8324       24
# 73419 Persuasion          8325       24
# 73420 Persuasion          8326       24
# 73421 Persuasion          8327       24
# 73422 Persuasion          8328       24

# %%
library(tidytext)
tidy_books <- original_books %>%
  unnest_tokens(word, text)

tidy_books
# Out:
#        book                linenumber chapter word
# 1      Sense & Sensibility  1         0       sense
# 2      Sense & Sensibility  1         0       and
# 3      Sense & Sensibility  1         0       sensibility
# 4      Sense & Sensibility  3         0       by
# 5      Sense & Sensibility  3         0       jane
# 6      Sense & Sensibility  3         0       austen
# 7      Sense & Sensibility  5         0       1811
# 8      Sense & Sensibility 10         1       chapter
# 9      Sense & Sensibility 10         1       1
# 10     Sense & Sensibility 13         1       the
# 11     Sense & Sensibility 13         1       family
# 12     Sense & Sensibility 13         1       of
# 13     Sense & Sensibility 13         1       dashwood
# 14     Sense & Sensibility 13         1       had
# 15     Sense & Sensibility 13         1       long
# 16     Sense & Sensibility 13         1       been
# 17     Sense & Sensibility 13         1       settled
# 18     Sense & Sensibility 13         1       in
# 19     Sense & Sensibility 13         1       sussex
# 20     Sense & Sensibility 13         1       their
# 21     Sense & Sensibility 13         1       estate
# 22     Sense & Sensibility 14         1       was
# 23     Sense & Sensibility 14         1       large
# 24     Sense & Sensibility 14         1       and
# 25     Sense & Sensibility 14         1       their
# 26     Sense & Sensibility 14         1       residence
# 27     Sense & Sensibility 14         1       was
# 28     Sense & Sensibility 14         1       at
# 29     Sense & Sensibility 14         1       norland
# 30     Sense & Sensibility 14         1       park
# ...    ...                 ...        ...     ...
# 725035 Persuasion          8321       24      but
# 725036 Persuasion          8321       24      she
# 725037 Persuasion          8321       24      must
# 725038 Persuasion          8321       24      pay
# 725039 Persuasion          8322       24      the
# 725040 Persuasion          8322       24      tax
# 725041 Persuasion          8322       24      of
# 725042 Persuasion          8322       24      quick
# 725043 Persuasion          8322       24      alarm
# 725044 Persuasion          8322       24      for
# 725045 Persuasion          8322       24      belonging
# 725046 Persuasion          8322       24      to
# 725047 Persuasion          8322       24      that
# 725048 Persuasion          8322       24      profession
# 725049 Persuasion          8322       24      which
# 725050 Persuasion          8322       24      is
# 725051 Persuasion          8322       24      if
# 725052 Persuasion          8323       24      possible
# 725053 Persuasion          8323       24      more
# 725054 Persuasion          8323       24      distinguished
# 725055 Persuasion          8323       24      in
# 725056 Persuasion          8323       24      its
# 725057 Persuasion          8323       24      domestic
# 725058 Persuasion          8323       24      virtues
# 725059 Persuasion          8323       24      than
# 725060 Persuasion          8323       24      in
# 725061 Persuasion          8323       24      its
# 725062 Persuasion          8324       24      national
# 725063 Persuasion          8324       24      importance
# 725064 Persuasion          8328       24      finis

# %%
data(stop_words)

tidy_books <- tidy_books %>%
  anti_join(stop_words)
# Out:
# Joining, by = "word"

# %%
tidy_books %>%
  count(word, sort = TRUE)
# Out:
#       word       n
# 1     miss       1855
# 2     time       1337
# 3     fanny       862
# 4     dear        822
# 5     lady        817
# 6     sir         806
# 7     day         797
# 8     emma        787
# 9     sister      727
# 10    house       699
# 11    elizabeth   687
# 12    elinor      623
# 13    hope        601
# 14    friend      593
# 15    family      578
# 16    mind        563
# 17    father      558
# 18    home        550
# 19    jane        550
# 20    mother      541
# 21    catherine   539
# 22    feelings    535
# 23    happy       534
# 24    moment      515
# 25    half        501
# 26    love        495
# 27    till        495
# 28    crawford    493
# 29    marianne    492
# 30    heart       470
# ...   ...        ...
# 13881 xxi        1
# 13882 xxii       1
# 13883 xxiii      1
# 13884 xxiv       1
# 13885 xxix       1
# 13886 xxv        1
# 13887 xxvi       1
# 13888 xxvii      1
# 13889 xxviii     1
# 13890 xxx        1
# 13891 xxxi       1
# 13892 xxxii      1
# 13893 xxxiii     1
# 13894 xxxiv      1
# 13895 xxxix      1
# 13896 xxxv       1
# 13897 xxxvi      1
# 13898 xxxvii     1
# 13899 xxxviii    1
# 13900 yawned     1
# 13901 yawning    1
# 13902 yawns      1
# 13903 year's     1
# 13904 yeomanry   1
# 13905 yeomen     1
# 13906 yestermorn 1
# 13907 younker    1
# 13908 your's     1
# 13909 youths     1
# 13910 zigzags    1

# %%
library(ggplot2)

tidy_books %>%
  count(word, sort = TRUE) %>%
  filter(n > 600) %>%
  mutate(word = reorder(word, n)) %>%
  ggplot(aes(word, n)) +
  geom_col() +
  xlab(NULL) +
  coord_flip()
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# plot without title

# %%
get_sentiments("afinn")
# Out:
#      word       score
# 1    abandon    -2
# 2    abandoned  -2
# 3    abandons   -2
# 4    abducted   -2
# 5    abduction  -2
# 6    abductions -2
# 7    abhor      -3
# 8    abhorred   -3
# 9    abhorrent  -3
# 10   abhors     -3
# 11   abilities   2
# 12   ability     2
# 13   aboard      1
# 14   absentee   -1
# 15   absentees  -1
# 16   absolve     2
# 17   absolved    2
# 18   absolves    2
# 19   absolving   2
# 20   absorbed    1
# 21   abuse      -3
# 22   abused     -3
# 23   abuses     -3
# 24   abusive    -3
# 25   accept      1
# 26   accepted    1
# 27   accepting   1
# 28   accepts     1
# 29   accident   -2
# 30   accidental -2
# ...  ...        ...
# 2447 worry      -3
# 2448 worrying   -3
# 2449 worse      -3
# 2450 worsen     -3
# 2451 worsened   -3
# 2452 worsening  -3
# 2453 worsens    -3
# 2454 worshiped   3
# 2455 worst      -3
# 2456 worth       2
# 2457 worthless  -2
# 2458 worthy      2
# 2459 wow         4
# 2460 wowow       4
# 2461 wowww       4
# 2462 wrathful   -3
# 2463 wreck      -2
# 2464 wrong      -2
# 2465 wronged    -2
# 2466 wtf        -4
# 2467 yeah        1
# 2468 yearning    1
# 2469 yeees       2
# 2470 yes         1
# 2471 youthful    2
# 2472 yucky      -2
# 2473 yummy       3
# 2474 zealot     -2
# 2475 zealots    -2
# 2476 zealous     2

# %%
library(gutenbergr)

hgwells <- gutenberg_download(c(35, 36, 5230, 159))
# Out:
# Determining mirror for Project Gutenberg from http://www.gutenberg.org/robot/harvest
# Using mirror http://aleph.gutenberg.org

# %%
# install.packages("gutenbergr")

# %%
library(gutenbergr)

hgwells <- gutenberg_download(c(35, 36, 5230, 159))

# %%
# library(tidytext)
# tidy_books <- hgwells %>%
#   unnest_tokens(word, text)

# tidy_books

# %%
data(stop_words)

tidy_hgwells <- tidy_books %>%
  anti_join(stop_words)
# Out:
# Joining, by = "word"

# %%
# tidy_books %>%
#   count(word, sort = TRUE)

# %%
tidy_hgwells <- hgwells %>%
  unnest_tokens(word, text) %>%
  anti_join(stop_words)
# Out:
# Joining, by = "word"

# %%
tidy_hgwells %>%
  count(word, sort = TRUE)
# Out:
#       word       n
# 1     time       454
# 2     people     302
# 3     door       260
# 4     heard      249
# 5     black      232
# 6     stood      229
# 7     white      222
# 8     hand       218
# 9     kemp       213
# 10    eyes       210
# 11    suddenly   210
# 12    found      200
# 13    invisible  200
# 14    night      200
# 15    day        193
# 16    montgomery 179
# 17    round      178
# 18    house      172
# 19    light      171
# 20    moment     171
# 21    head       166
# 22    hall       165
# 23    martians   163
# 24    looked     161
# 25    voice      155
# 26    strange    149
# 27    feet       147
# 28    left       147
# 29    mind       147
# 30    red        140
# ...   ...        ...
# 11739 wrecks     1
# 11740 wrested    1
# 11741 wretch's   1
# 11742 wretcheder 1
# 11743 wriggle    1
# 11744 wrists     1
# 11745 writ       1
# 11746 writer's   1
# 11747 writers    1
# 11748 wropped    1
# 11749 wrung      1
# 11750 yachts     1
# 11751 yawed      1
# 11752 yawp       1
# 11753 yellowish  1
# 11754 yells      1
# 11755 yiddish    1
# 11756 yielding   1
# 11757 yokel      1
# 11758 yokels     1
# 11759 yore       1
# 11760 york       1
# 11761 youngish   1
# 11762 youthful   1
# 11763 youths     1
# 11764 zenithward 1
# 11765 zodiac     1
# 11766 zodiacal   1
# 11767 zones      1
# 11768 zouaves    1

# %%
library(ggplot2)

tidy_hgwells %>%
  count(word, sort = TRUE) %>%
  filter(n > 600) %>%
  mutate(word = reorder(word, n)) %>%
  ggplot(aes(word, n)) +
  geom_col() +
  xlab(NULL) +
  coord_flip()
# Out:
# plot without title

# %%
bronte <- gutenberg_download(c(1260, 768, 969, 9182, 767))

# %%
tidy_bronte <- bronte %>%
  unnest_tokens(word, text) %>%
  anti_join(stop_words)
# Out:
# Joining, by = "word"

# %%
tidy_bronte %>%
  count(word, sort = TRUE)
# Out:
#       word       n
# 1     time       1065
# 2     miss        855
# 3     day         827
# 4     hand        768
# 5     eyes        713
# 6     night       647
# 7     heart       638
# 8     looked      601
# 9     door        592
# 10    half        586
# 11    till        584
# 12    house       582
# 13    love        566
# 14    life        561
# 15    heard       510
# 16    left        492
# 17    mind        491
# 18    sir         489
# 19    head        487
# 20    home        461
# 21    heathcliff  421
# 22    mother      417
# 23    moment      409
# 24    found       405
# 25    morning     405
# 26    told        405
# 27    leave       404
# 28    lady        403
# 29    round       386
# 30    stood       374
# ...   ...        ...
# 23012 yaas       1
# 23013 yah'll     1
# 23014 yankee     1
# 23015 yarns      1
# 23016 yeah       1
# 23017 yelling    1
# 23018 yelp       1
# 23019 yelped     1
# 23020 yeth       1
# 23021 yieldingly 1
# 23022 yill       1
# 23023 yoak       1
# 23024 yond       1
# 23025 yond's     1
# 23026 yorkshire  1
# 23027 youngsters 1
# 23028 yourseln   1
# 23029 yule       1
# 23030 zag        1
# 23031 zealot     1
# 23032 zealots    1
# 23033 zealously  1
# 23034 zele       1
# 23035 zembla     1
# 23036 zephyr     1
# 23037 zig        1
# 23038 zigzag     1
# 23039 zigzags    1
# 23040 zornes     1
# 23041 zurueck    1

# %%
library(tidyr)

frequency <- bind_rows(mutate(tidy_bronte, author = "Brontë Sisters"),
                       mutate(tidy_hgwells, author = "H.G. Wells"), 
                       mutate(tidy_books, author = "Jane Austen")) %>% 
  mutate(word = str_extract(word, "[a-z']+")) %>%
  count(author, word) %>%
  group_by(author) %>%
  mutate(proportion = n / sum(n)) %>% 
  select(-n) %>% 
  spread(author, proportion) %>% 
  gather(author, proportion, `Brontë Sisters`:`H.G. Wells`)

# %%
library(scales)
jpeg("rplot.jpg")
# expect a warning about rows with missing values being removed
ggplot(frequency, aes(x = proportion, y = `Jane Austen`, color = abs(`Jane Austen` - proportion))) +
  geom_abline(color = "gray40", lty = 2) +
  geom_jitter(alpha = 0.1, size = 2.5, width = 0.3, height = 0.3) +
  geom_text(aes(label = word), check_overlap = TRUE, vjust = 1.5) +
  scale_x_log10(labels = percent_format()) +
  scale_y_log10(labels = percent_format()) +
  scale_color_gradient(limits = c(0, 0.001), low = "darkslategray4", high = "gray75") +
  facet_wrap(~author, ncol = 2) +
  theme(legend.position="none") +
  labs(y = "Jane Austen", x = NULL)
dev.off()
# Out:
# Warning message:
# “Removed 41350 rows containing missing values (geom_point).”Warning message:
# “Removed 41352 rows containing missing values (geom_text).”
# pdf
#   2

# %%
cor.test(data = frequency[frequency$author == "Brontë Sisters",],
         ~ proportion + `Jane Austen`)
# Out:
# 	Pearson's product-moment correlation
#
# data:  proportion and Jane Austen
# t = 119.65, df = 10404, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.7527887 0.7689659
# sample estimates:
#       cor
# 0.7609955

# %%
cor.test(data = frequency[frequency$author == "H.G. Wells",], 
         ~ proportion + `Jane Austen`)
# Out:
# 	Pearson's product-moment correlation
#
# data:  proportion and Jane Austen
# t = 36.436, df = 6052, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.4032643 0.4445870
# sample estimates:
#       cor
# 0.4241464

# %%
library(janeaustenr)
library(dplyr)
library(stringr)

tidy_books <- austen_books() %>%
  group_by(book) %>%
  mutate(linenumber = row_number(),
         chapter = cumsum(str_detect(text, regex("^chapter [\\divxlc]", 
                                                 ignore_case = TRUE)))) %>%
  ungroup() %>%
  unnest_tokens(word, text)

# %%
nrc_joy <- get_sentiments("nrc") %>% 
  filter(sentiment == "joy")

tidy_books %>%
  filter(book == "Emma") %>%
  inner_join(nrc_joy) %>%
  count(word, sort = TRUE)
# Out:
# Joining, by = "word"
#     word        n
# 1   good        359
# 2   young       192
# 3   friend      166
# 4   hope        143
# 5   happy       125
# 6   love        117
# 7   deal         92
# 8   found        92
# 9   present      89
# 10  kind         82
# 11  happiness    76
# 12  pretty       68
# 13  true         66
# 14  comfort      65
# 15  spirits      64
# 16  marry        63
# 17  mother       57
# 18  feeling      56
# 19  satisfied    52
# 20  affection    50
# 21  glad         50
# 22  daughter     47
# 23  pleased      47
# 24  smile        44
# 25  respect      43
# 26  delightful   41
# 27  pleasant     41
# 28  fortune      39
# 29  engaged      38
# 30  fancy        38
# ... ...         ...
# 274 inheritance 1
# 275 inspiration 1
# 276 inspire     1
# 277 inspired    1
# 278 intimately  1
# 279 kindred     1
# 280 lamb        1
# 281 laurels     1
# 282 liquor      1
# 283 mighty      1
# 284 mirth       1
# 285 opportune   1
# 286 picnic      1
# 287 quaint      1
# 288 rave        1
# 289 raving      1
# 290 rejoicing   1
# 291 remedy      1
# 292 respite     1
# 293 romantic    1
# 294 serenity    1
# 295 shopping    1
# 296 sunshine    1
# 297 surprise    1
# 298 thriving    1
# 299 triumphant  1
# 300 vacation    1
# 301 whim        1
# 302 winning     1
# 303 worship     1

# %%
library(tidyr)

jane_austen_sentiment <- tidy_books %>%
  inner_join(get_sentiments("bing")) %>%
  count(book, index = linenumber %/% 80, sentiment) %>%
  spread(sentiment, n, fill = 0) %>%
  mutate(sentiment = positive - negative)
# Out:
# Joining, by = "word"

# %%
library(ggplot2)

ggplot(jane_austen_sentiment, aes(index, sentiment, fill = book)) +
  geom_col(show.legend = FALSE) +
  facet_wrap(~book, ncol = 2, scales = "free_x")
# Out:
# plot without title

# %%
pride_prejudice <- tidy_books %>% 
  filter(book == "Pride & Prejudice")

pride_prejudice
# Out:
#        book              linenumber chapter word
# 1      Pride & Prejudice  1         0       pride
# 2      Pride & Prejudice  1         0       and
# 3      Pride & Prejudice  1         0       prejudice
# 4      Pride & Prejudice  3         0       by
# 5      Pride & Prejudice  3         0       jane
# 6      Pride & Prejudice  3         0       austen
# 7      Pride & Prejudice  7         1       chapter
# 8      Pride & Prejudice  7         1       1
# 9      Pride & Prejudice 10         1       it
# 10     Pride & Prejudice 10         1       is
# 11     Pride & Prejudice 10         1       a
# 12     Pride & Prejudice 10         1       truth
# 13     Pride & Prejudice 10         1       universally
# 14     Pride & Prejudice 10         1       acknowledged
# 15     Pride & Prejudice 10         1       that
# 16     Pride & Prejudice 10         1       a
# 17     Pride & Prejudice 10         1       single
# 18     Pride & Prejudice 10         1       man
# 19     Pride & Prejudice 10         1       in
# 20     Pride & Prejudice 10         1       possession
# 21     Pride & Prejudice 11         1       of
# 22     Pride & Prejudice 11         1       a
# 23     Pride & Prejudice 11         1       good
# 24     Pride & Prejudice 11         1       fortune
# 25     Pride & Prejudice 11         1       must
# 26     Pride & Prejudice 11         1       be
# 27     Pride & Prejudice 11         1       in
# 28     Pride & Prejudice 11         1       want
# 29     Pride & Prejudice 11         1       of
# 30     Pride & Prejudice 11         1       a
# ...    ...               ...        ...     ...
# 122175 Pride & Prejudice 13028      61      elizabeth
# 122176 Pride & Prejudice 13028      61      really
# 122177 Pride & Prejudice 13028      61      loved
# 122178 Pride & Prejudice 13028      61      them
# 122179 Pride & Prejudice 13028      61      and
# 122180 Pride & Prejudice 13028      61      they
# 122181 Pride & Prejudice 13028      61      were
# 122182 Pride & Prejudice 13028      61      both
# 122183 Pride & Prejudice 13028      61      ever
# 122184 Pride & Prejudice 13029      61      sensible
# 122185 Pride & Prejudice 13029      61      of
# 122186 Pride & Prejudice 13029      61      the
# 122187 Pride & Prejudice 13029      61      warmest
# 122188 Pride & Prejudice 13029      61      gratitude
# 122189 Pride & Prejudice 13029      61      towards
# 122190 Pride & Prejudice 13029      61      the
# 122191 Pride & Prejudice 13029      61      persons
# 122192 Pride & Prejudice 13029      61      who
# 122193 Pride & Prejudice 13029      61      by
# 122194 Pride & Prejudice 13029      61      bringing
# 122195 Pride & Prejudice 13030      61      her
# 122196 Pride & Prejudice 13030      61      into
# 122197 Pride & Prejudice 13030      61      derbyshire
# 122198 Pride & Prejudice 13030      61      had
# 122199 Pride & Prejudice 13030      61      been
# 122200 Pride & Prejudice 13030      61      the
# 122201 Pride & Prejudice 13030      61      means
# 122202 Pride & Prejudice 13030      61      of
# 122203 Pride & Prejudice 13030      61      uniting
# 122204 Pride & Prejudice 13030      61      them

# %%
library(tidytext)

get_sentiments("afinn")
# Out:
#      word       score
# 1    abandon    -2
# 2    abandoned  -2
# 3    abandons   -2
# 4    abducted   -2
# 5    abduction  -2
# 6    abductions -2
# 7    abhor      -3
# 8    abhorred   -3
# 9    abhorrent  -3
# 10   abhors     -3
# 11   abilities   2
# 12   ability     2
# 13   aboard      1
# 14   absentee   -1
# 15   absentees  -1
# 16   absolve     2
# 17   absolved    2
# 18   absolves    2
# 19   absolving   2
# 20   absorbed    1
# 21   abuse      -3
# 22   abused     -3
# 23   abuses     -3
# 24   abusive    -3
# 25   accept      1
# 26   accepted    1
# 27   accepting   1
# 28   accepts     1
# 29   accident   -2
# 30   accidental -2
# ...  ...        ...
# 2447 worry      -3
# 2448 worrying   -3
# 2449 worse      -3
# 2450 worsen     -3
# 2451 worsened   -3
# 2452 worsening  -3
# 2453 worsens    -3
# 2454 worshiped   3
# 2455 worst      -3
# 2456 worth       2
# 2457 worthless  -2
# 2458 worthy      2
# 2459 wow         4
# 2460 wowow       4
# 2461 wowww       4
# 2462 wrathful   -3
# 2463 wreck      -2
# 2464 wrong      -2
# 2465 wronged    -2
# 2466 wtf        -4
# 2467 yeah        1
# 2468 yearning    1
# 2469 yeees       2
# 2470 yes         1
# 2471 youthful    2
# 2472 yucky      -2
# 2473 yummy       3
# 2474 zealot     -2
# 2475 zealots    -2
# 2476 zealous     2

# %%
get_sentiments("bing")
# Out:
#      word          sentiment
# 1    2-faced       negative
# 2    2-faces       negative
# 3    a+            positive
# 4    abnormal      negative
# 5    abolish       negative
# 6    abominable    negative
# 7    abominably    negative
# 8    abominate     negative
# 9    abomination   negative
# 10   abort         negative
# 11   aborted       negative
# 12   aborts        negative
# 13   abound        positive
# 14   abounds       positive
# 15   abrade        negative
# 16   abrasive      negative
# 17   abrupt        negative
# 18   abruptly      negative
# 19   abscond       negative
# 20   absence       negative
# 21   absent-minded negative
# 22   absentee      negative
# 23   absurd        negative
# 24   absurdity     negative
# 25   absurdly      negative
# 26   absurdness    negative
# 27   abundance     positive
# 28   abundant      positive
# 29   abuse         negative
# 30   abused        negative
# ...  ...           ...
# 6759 wrestle       negative
# 6760 wretch        negative
# 6761 wretched      negative
# 6762 wretchedly    negative
# 6763 wretchedness  negative
# 6764 wrinkle       negative
# 6765 wrinkled      negative
# 6766 wrinkles      negative
# 6767 wrip          negative
# 6768 wripped       negative
# 6769 wripping      negative
# 6770 writhe        negative
# 6771 wrong         negative
# 6772 wrongful      negative
# 6773 wrongly       negative
# 6774 wrought       negative
# 6775 yawn          negative
# 6776 yay           positive
# 6777 youthful      positive
# 6778 zap           negative
# 6779 zapped        negative
# 6780 zaps          negative
# 6781 zeal          positive
# 6782 zealot        negative
# 6783 zealous       negative
# 6784 zealously     negative
# 6785 zenith        positive
# 6786 zest          positive
# 6787 zippy         positive
# 6788 zombie        negative

# %%
get_sentiments("nrc")
# Out:
#       word        sentiment
# 1     abacus      trust
# 2     abandon     fear
# 3     abandon     negative
# 4     abandon     sadness
# 5     abandoned   anger
# 6     abandoned   fear
# 7     abandoned   negative
# 8     abandoned   sadness
# 9     abandonment anger
# 10    abandonment fear
# 11    abandonment negative
# 12    abandonment sadness
# 13    abandonment surprise
# 14    abba        positive
# 15    abbot       trust
# 16    abduction   fear
# 17    abduction   negative
# 18    abduction   sadness
# 19    abduction   surprise
# 20    aberrant    negative
# 21    aberration  disgust
# 22    aberration  negative
# 23    abhor       anger
# 24    abhor       disgust
# 25    abhor       fear
# 26    abhor       negative
# 27    abhorrent   anger
# 28    abhorrent   disgust
# 29    abhorrent   fear
# 30    abhorrent   negative
# ...   ...         ...
# 13872 yellows     negative
# 13873 yelp        anger
# 13874 yelp        fear
# 13875 yelp        negative
# 13876 yelp        surprise
# 13877 young       anticipation
# 13878 young       joy
# 13879 young       positive
# 13880 young       surprise
# 13881 younger     positive
# 13882 youth       anger
# 13883 youth       anticipation
# 13884 youth       fear
# 13885 youth       joy
# 13886 youth       positive
# 13887 youth       surprise
# 13888 zany        surprise
# 13889 zeal        anticipation
# 13890 zeal        joy
# 13891 zeal        positive
# 13892 zeal        surprise
# 13893 zeal        trust
# 13894 zealous     joy
# 13895 zealous     positive
# 13896 zealous     trust
# 13897 zest        anticipation
# 13898 zest        joy
# 13899 zest        positive
# 13900 zest        trust
# 13901 zip         negative

# %%
afinn <- pride_prejudice %>% 
  inner_join(get_sentiments("afinn")) %>% 
  group_by(index = linenumber %/% 80) %>% 
  summarise(sentiment = sum(value)) %>% 
  mutate(method = "AFINN")
get_sentiments("nrc") %>% 
     filter(sentiment %in% c("positive", 
                             "negative")) %>% 
  count(sentiment)

get_sentiments("bing") %>% 
  count(sentiment)
bing_and_nrc <- bind_rows(pride_prejudice %>% 
                            inner_join(get_sentiments("bing")) %>%
                            mutate(method = "Bing et al."),
                          pride_prejudice %>% 
                            inner_join(get_sentiments("nrc") %>% 
                                         filter(sentiment %in% c("positive", 
                                                                 "negative"))) %>%
                            mutate(method = "NRC")) %>%
  count(method, index = linenumber %/% 80, sentiment) %>%
  spread(sentiment, n, fill = 0) %>%
  mutate(sentiment = positive - negative)
# Out:
# Joining, by = "word"
# Error: 找不到物件 'value'
# Traceback:
#
# 1. pride_prejudice %>% inner_join(get_sentiments("afinn")) %>% group_by(index = linenumber%/%80) %>%
#  .     summarise(sentiment = sum(value)) %>% mutate(method = "AFINN")
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. summarise(., sentiment = sum(value))
# 9. summarise.tbl_df(., sentiment = sum(value))
# 10. summarise_impl(.data, dots, environment(), caller_env())

# %%
get_sentiments("nrc") %>% 
     filter(sentiment %in% c("positive", 
                             "negative")) %>% 
  count(sentiment)

get_sentiments("bing") %>% 
  count(sentiment)
# Out:
#   sentiment n
# 1 negative  3324
# 2 positive  2312
#   sentiment n
# 1 negative  4782
# 2 positive  2006

# %%
bing_word_counts <- tidy_books %>%
  inner_join(get_sentiments("bing")) %>%
  count(word, sentiment, sort = TRUE) %>%
  ungroup()

bing_word_counts
# Out:
# Joining, by = "word"
#      word            sentiment n
# 1    miss            negative  1855
# 2    well            positive  1523
# 3    good            positive  1380
# 4    great           positive   981
# 5    like            positive   725
# 6    better          positive   639
# 7    enough          positive   613
# 8    happy           positive   534
# 9    love            positive   495
# 10   pleasure        positive   462
# 11   poor            negative   424
# 12   happiness       positive   369
# 13   right           positive   329
# 14   best            positive   323
# 15   comfort         positive   292
# 16   doubt           negative   281
# 17   affection       positive   272
# 18   perfectly       positive   271
# 19   glad            positive   263
# 20   agreeable       positive   242
# 21   pretty          positive   242
# 22   object          negative   233
# 23   ready           positive   226
# 24   sorry           negative   219
# 25   fine            positive   216
# 26   impossible      negative   215
# 27   regard          positive   214
# 28   wonder          positive   206
# 29   kindness        positive   200
# 30   afraid          negative   198
# ...  ...             ...       ...
# 2556 unfulfilled     negative  1
# 2557 ungovernable    negative  1
# 2558 unproductive    negative  1
# 2559 unquestionable  positive  1
# 2560 unselfish       positive  1
# 2561 unsettle        negative  1
# 2562 unsophisticated negative  1
# 2563 unsuccessful    negative  1
# 2564 unyielding      negative  1
# 2565 upbraid         negative  1
# 2566 useable         positive  1
# 2567 vehement        negative  1
# 2568 vehemently      negative  1
# 2569 vexing          negative  1
# 2570 villainous      negative  1
# 2571 villains        negative  1
# 2572 virulence       negative  1
# 2573 volatility      negative  1
# 2574 vulnerable      negative  1
# 2575 warped          negative  1
# 2576 wary            negative  1
# 2577 wasteful        negative  1
# 2578 weep            negative  1
# 2579 whine           negative  1
# 2580 winner          positive  1
# 2581 winning         positive  1
# 2582 wins            positive  1
# 2583 worries         negative  1
# 2584 wounds          negative  1
# 2585 wreck           negative  1

# %%
bing_word_counts %>%
  group_by(sentiment) %>%
  top_n(10) %>%
  ungroup() %>%
  mutate(word = reorder(word, n)) %>%
  ggplot(aes(word, n, fill = sentiment)) +
  geom_col(show.legend = FALSE) +
  facet_wrap(~sentiment, scales = "free_y") +
  labs(y = "Contribution to sentiment",
       x = NULL) +
  coord_flip()
# Out:
# Selecting by n
# plot without title

# %%
library(wordcloud)

tidy_books %>%
  anti_join(stop_words) %>%
  count(word) %>%
  with(wordcloud(word, n, max.words = 100))
# Out:
# Error in library(wordcloud): there is no package called ‘wordcloud’
# Traceback:
#
# 1. library(wordcloud)

# %%
install.packages (“tm”)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:19: unexpected input
# 1: install.packages (<e2>
#                       ^
# Traceback:

# %%
install.packages(“wordcloud”)
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:18: unexpected input
# 1:
# 2: install.packages(<e2>
#                     ^
# Traceback:

# %%
install.packages("wordcloud")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(wordcloud)

tidy_books %>%
  anti_join(stop_words) %>%
  count(word) %>%
  with(wordcloud(word, n, max.words = 100))
# Out:
# Loading required package: RColorBrewer
# Joining, by = "word"
# plot without title

# %%
library(wordcloud)

tidy_books %>%
  anti_join(stop_words) %>%
  count(word) %>%
  with(wordcloud(word, n, max.words = 100))
